# %% [markdown]
# ### Pandas DataFrames

# %%
import numpy as np 
import pandas as pd
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5,7),[1,2,3,4,5],['T','U','V','W','X','Y','Z'])
df
# Out:
#           T         U         V         W         X         Y         Z
# 1  0.890950  0.290230  0.392372 -0.521326  1.180511 -0.507833  1.000442
# 2  1.735856 -0.372495 -0.332359  0.052514  1.539560 -1.473029  0.512366
# 3  1.104707  0.451780  0.328972 -0.813794 -0.910293  1.488370  1.435349
# 4  1.834926 -1.930662  0.184121 -0.131765 -0.816331 -0.948155  0.933952
# 5 -1.290103  1.462288  0.065532 -1.375244 -1.585230  0.047519 -0.027028

# %%
# Ex 1:-

df['Z']
# Out:
# 1    1.000442
# 2    0.512366
# 3    1.435349
# 4    0.933952
# 5   -0.027028
# Name: Z, dtype: float64

# %%
# Ex 2:-

df[['T', 'V', 'Z']]
# Out:
#           T         V         Z
# 1  0.890950  0.392372  1.000442
# 2  1.735856 -0.332359  0.512366
# 3  1.104707  0.328972  1.435349
# 4  1.834926  0.184121  0.933952
# 5 -1.290103  0.065532 -0.027028

# %%
# Ex 2ii:- Getting columns V, Y, Z
cols = ['V', 'Y', 'Z']
df[cols]
# Out:
#           V         Y         Z
# 1  0.392372 -0.507833  1.000442
# 2 -0.332359 -1.473029  0.512366
# 3  0.328972  1.488370  1.435349
# 4  0.184121 -0.948155  0.933952
# 5  0.065532  0.047519 -0.027028

# %%
# Ex 3:- Adding another column to the DataFrame...

df['ext'] = df['V'] + df['X']
df['ext']
# Out:
# 1    1.572884
# 2    1.207201
# 3   -0.581320
# 4   -0.632210
# 5   -1.519698
# Name: ext, dtype: float64

# %%
df
# Out:
#           T         U         V         W         X         Y         Z  \
# 1  0.890950  0.290230  0.392372 -0.521326  1.180511 -0.507833  1.000442
# 2  1.735856 -0.372495 -0.332359  0.052514  1.539560 -1.473029  0.512366
# 3  1.104707  0.451780  0.328972 -0.813794 -0.910293  1.488370  1.435349
# 4  1.834926 -1.930662  0.184121 -0.131765 -0.816331 -0.948155  0.933952
# 5 -1.290103  1.462288  0.065532 -1.375244 -1.585230  0.047519 -0.027028
#
#         ext
# 1  1.572884
# 2  1.207201
# 3 -0.581320
# 4 -0.632210
# 5 -1.519698

# %%
# To Delete a certain column, we use the drop() method...
# "inplace=True" ensures that the col deletion is invoked permanently

# Ex 4:-
df.drop('W',axis=1,inplace=True)
df
# Out:
#           T         U         V         X         Y         Z       ext
# 1  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# 2  1.735856 -0.372495 -0.332359  1.539560 -1.473029  0.512366  1.207201
# 3  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# 4  1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.632210
# 5 -1.290103  1.462288  0.065532 -1.585230  0.047519 -0.027028 -1.519698

# %%
# To get the rows in a DataFrame, you use loc and iloc...
# "iloc": starts its index at 0 to get the numeric based index, WHILE, "loc": starts its index at 1 to get the location based index...

# Ex 5i:-
df.loc[3]
# Out:
# T      1.104707
# U      0.451780
# V      0.328972
# X     -0.910293
# Y      1.488370
# Z      1.435349
# ext   -0.581320
# Name: 3, dtype: float64

# %%
# Ex 5ii:-
df.iloc[2]
# Out:
# T      1.104707
# U      0.451780
# V      0.328972
# X     -0.910293
# Y      1.488370
# Z      1.435349
# ext   -0.581320
# Name: 3, dtype: float64

# %%
# Ex 6:- Getting subset of rows and cloumns....

# In grabbing data from multiple rows & cols, you can only do slicing w/"df.loc"
#"df.iloc" doesn't work with slicing in pandas Dataframes, AND you must use numeric indexers (i.e 0,1 etc) when getting data, even if your rows/cols are labelled in strings.

df
# Out:
#           T         U         V         X         Y         Z       ext
# 1  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# 2  1.735856 -0.372495 -0.332359  1.539560 -1.473029  0.512366  1.207201
# 3  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# 4  1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.632210
# 5 -1.290103  1.462288  0.065532 -1.585230  0.047519 -0.027028 -1.519698

# %%
df.loc[3:5,'X':]
# Out:
#           X         Y         Z       ext
# 3 -0.910293  1.488370  1.435349 -0.581320
# 4 -0.816331 -0.948155  0.933952 -0.632210
# 5 -1.585230  0.047519 -0.027028 -1.519698

# %%
df.loc[2,'V']
# Out:
# -0.33235873520852705

# %%
df.iloc[[3,4],[0,3,5]]
# Out:
#           T         X         Z
# 4  1.834926 -0.816331  0.933952
# 5 -1.290103 -1.585230 -0.027028

# %% [markdown]
# ### Conditional Selection in Pandas

# %%
df
# Out:
#           T         U         V         X         Y         Z       ext
# 1  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# 2  1.735856 -0.372495 -0.332359  1.539560 -1.473029  0.512366  1.207201
# 3  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# 4  1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.632210
# 5 -1.290103  1.462288  0.065532 -1.585230  0.047519 -0.027028 -1.519698

# %%
# Ex 7:-
bool_df = df > 0
bool_df
# Out:
#        T      U      V      X      Y      Z    ext
# 1   True   True   True   True  False   True   True
# 2   True  False  False   True  False   True   True
# 3   True   True   True  False   True   True  False
# 4   True  False   True  False  False   True  False
# 5  False   True   True  False   True  False  False

# %%
# Ex 8:- The "Nan" result signifies that the value is False

df[bool_df]
# Out:
#           T         U         V         X         Y         Z       ext
# 1  0.890950  0.290230  0.392372  1.180511       NaN  1.000442  1.572884
# 2  1.735856       NaN       NaN  1.539560       NaN  0.512366  1.207201
# 3  1.104707  0.451780  0.328972       NaN  1.488370  1.435349       NaN
# 4  1.834926       NaN  0.184121       NaN       NaN  0.933952       NaN
# 5       NaN  1.462288  0.065532       NaN  0.047519       NaN       NaN

# %%
# Ex 9i:- Filtering only the "True" values...

df_bool = df['U'] > 0
df_bool
# Out:
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# Name: U, dtype: bool

# %%
df[df_bool]          # The DataFrame returns only the subset of "True" values....
# Out:
#           T         U         V         X         Y         Z       ext
# 1  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# 3  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# 5 -1.290103  1.462288  0.065532 -1.585230  0.047519 -0.027028 -1.519698

# %%
# Ex 9ii:-

df_booll = df['Z'] < 0
df_booll
# Out:
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# Name: Z, dtype: bool

# %%
df_result = df[df_booll]          # The DataFrame returns only the True values
df_result
# Out:
#           T         U         V        X         Y         Z       ext
# 5 -1.290103  1.462288  0.065532 -1.58523  0.047519 -0.027028 -1.519698

# %% [markdown]
# ### Dealing with multiple conditional selection

# %%
# Ex 10:- 

df
# Out:
#           T         U         V         X         Y         Z       ext
# 1  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# 2  1.735856 -0.372495 -0.332359  1.539560 -1.473029  0.512366  1.207201
# 3  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# 4  1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.632210
# 5 -1.290103  1.462288  0.065532 -1.585230  0.047519 -0.027028 -1.519698

# %%
df['T'] > 0
# Out:
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# Name: T, dtype: bool

# %%
# With pandas, you can't use the "and"/"or" when working w/multiple conditions
# We use "and" as:- &; "or" as:- |

df[(df['T'] > 0) & (df['X'] < 1)]
# Out:
#           T         U         V         X         Y         Z      ext
# 3  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.58132
# 4  1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.63221

# %%
df[(df['T'] > 0) | (df['U'] < 1)]
# Out:
#           T         U         V         X         Y         Z       ext
# 1  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# 2  1.735856 -0.372495 -0.332359  1.539560 -1.473029  0.512366  1.207201
# 3  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# 4  1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.632210

# %%
# But Pandas can only deal with single instances of boolean ("and"/"or") values...

True and True
# Out:
# True

# %% [markdown]
# ### Resetting Indexes

# %%
# Ex 11:

df
# Out:
#           T         U         V         X         Y         Z       ext
# 1  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# 2  1.735856 -0.372495 -0.332359  1.539560 -1.473029  0.512366  1.207201
# 3  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# 4  1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.632210
# 5 -1.290103  1.462288  0.065532 -1.585230  0.047519 -0.027028 -1.519698

# %%
df.reset_index()             # This method resets the index of the DataFrame to numericals (from 0 to....)
# Out:
#    index         T         U         V         X         Y         Z       ext
# 0      1  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# 1      2  1.735856 -0.372495 -0.332359  1.539560 -1.473029  0.512366  1.207201
# 2      3  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# 3      4  1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.632210
# 4      5 -1.290103  1.462288  0.065532 -1.585230  0.047519 -0.027028 -1.519698

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#           T         U         V         X         Y         Z       ext
# 0  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# 1  1.735856 -0.372495 -0.332359  1.539560 -1.473029  0.512366  1.207201
# 2  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# 3  1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.632210
# 4 -1.290103  1.462288  0.065532 -1.585230  0.047519 -0.027028 -1.519698

# %%
# Ex 11ii:-

new_index = 'Toronto Seattle SF NY Boston'.split()
new_index
# Out:
# ['Toronto', 'Seattle', 'SF', 'NY', 'Boston']

# %%
# Adding a new column to the DataFrame...
df['Cities'] = new_index
df
# Out:
#           T         U         V         X         Y         Z       ext  \
# 0  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# 1  1.735856 -0.372495 -0.332359  1.539560 -1.473029  0.512366  1.207201
# 2  1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# 3  1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.632210
# 4 -1.290103  1.462288  0.065532 -1.585230  0.047519 -0.027028 -1.519698
#
#     Cities
# 0  Toronto
# 1  Seattle
# 2       SF
# 3       NY
# 4   Boston

# %%
# Making our column "Cities" in the DataFrame to be the index... 
# Remember that by not including "inplace=True" we're invoking a permanent change to the index...

# Ex 11iii:-
df.set_index("Cities")
# Out:
#                 T         U         V         X         Y         Z       ext
# Cities
# Toronto  0.890950  0.290230  0.392372  1.180511 -0.507833  1.000442  1.572884
# Seattle  1.735856 -0.372495 -0.332359  1.539560 -1.473029  0.512366  1.207201
# SF       1.104707  0.451780  0.328972 -0.910293  1.488370  1.435349 -0.581320
# NY       1.834926 -1.930662  0.184121 -0.816331 -0.948155  0.933952 -0.632210
# Boston  -1.290103  1.462288  0.065532 -1.585230  0.047519 -0.027028 -1.519698
